# %% [markdown]
# <a href="https://colab.research.google.com/github/bukhtiarhaider/CE888/blob/main/Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data = pd.read_csv('/content/drive/MyDrive/jester-data-1.csv')

data.drop(data.columns[0], axis=1, inplace=True)
data = data.replace(99, np.nan) #Replacing all '99's to np.nan
data.describe()
# Out:
#               -7.82          8.79         -9.66         -8.16         -7.52  \
# count  16451.000000  18183.000000  16641.000000  15607.000000  24976.000000
# mean       0.905104      0.207988      0.317174     -1.448684      0.403874
# std        5.171508      5.597119      5.399415      5.234546      5.255566
# min       -9.950000     -9.950000     -9.950000     -9.950000     -9.950000
# 25%       -2.670000     -4.420000     -4.030000     -5.870000     -3.690000
# 50%        1.600000      0.830000      0.780000     -1.460000      1.120000
# 75%        4.900000      4.810000      4.660000      2.520000      4.470000
# max        9.370000      9.370000      9.370000      9.370000      9.370000
#
#                -8.5         -9.85          4.17         -8.98         -4.76  \
# count  20430.000000  24975.000000  24980.000000  15751.000000  20323.000000
# mean       1.594941     -0.429285     -0.624277     -0.556496      1.301529
# ...
